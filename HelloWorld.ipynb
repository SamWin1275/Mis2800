# %% [markdown]
# <a href="https://colab.research.google.com/github/SamWin1275/Mis2800/blob/main/HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello World")
# Out:
# hello World

# %%
print ("mis is best!")
# Out:
# mis is best!
